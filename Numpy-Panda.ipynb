# %%
0# Shift + enter
print("Hello world,.")
# Out:
# Hello world,.

# %% [markdown]
# <img width = 500 src="https://drive.google.com/uc?id=1arJhLlzbr_Rf7ONxpkzo726mLbTyLb_p">

# %% [markdown]
# # Numpy

# %% [markdown]
# # New Section

# %%
import numpy as np

# %%
arr1 = np.array([1, 2, 3, 4, 5])

# %%
print(arr1)
# Out:
# [1 2 3 4 5]

# %%
print(arr1*2)
# Out:
# [ 2  4  6  8 10]

# %%
print(arr1 + 10)
# Out:
# [11 12 13 14 15]

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
arr1.ndim
# Out:
# 1

# %%
len(arr1)
# Out:
# 5

# %%
arr1.shape
# Out:
# (5,)

# %%
arr2 = np.array( [[1, 2] , [3, 4]] )
arr2
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
arr2.ndim
# Out:
# 2

# %%
arr2.shape
# Out:
# (2, 2)

# %%
arr2 = np.arange(10, 17)
arr2
# Out:
# array([10, 11, 12, 13, 14, 15, 16])

# %%
m1 = np.arange(20, 38, 2)
m1
# Out:
# array([20, 22, 24, 26, 28, 30, 32, 34, 36])

# %%
# give me 0th element
m1[0]
# Out:
# 20

# %%
m1[7]
# Out:
# 34

# %%
# negative indexing
m1[-2]
# Out:
# 34

# %%
m1[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-dcc3f491c2a0> in <module>
# ----> 1 m1[10]
#
# IndexError: index 10 is out of bounds for axis 0 with size 9

# %%
m1
# Out:
# array([20, 22, 24, 26, 28, 30, 32, 34, 36])

# %%
m1[ [2, 0, -1, 8, 3] ]
# Out:
# array([24, 20, 36, 36, 26])

# %%
# Slicing
# m1[start_idx : end_idx]

m1[ 1 : 4]
# Out:
# array([22, 24, 26])

# %%
m1[ 4  :  8 ]
# Out:
# array([28, 30, 32, 34])

# %%
m1[-5 : -1]
# Out:
# array([28, 30, 32, 34])

# %%
# Fancy Indexing

# %%
m1
# Out:
# array([20, 22, 24, 26, 28, 30, 32, 34, 36])

# %%
mask = m1 < 30
mask
# Out:
# array([ True,  True,  True,  True,  True, False, False, False, False])

# %%
m1[mask]
# Out:
# array([20, 22, 24, 26, 28])

# %%
m1[ m1< 30 ]
# Out:
# array([20, 22, 24, 26, 28])

# %%
m1[ m1%2==0 ]
# Out:
# array([20, 22, 24, 26, 28, 30, 32, 34, 36])

# %%
a = np.array([1,3,5])
b = np.array([2,1,1])

print(a)
print(b)
# Out:
# [1 3 5]
# [2 1 1]

# %%
a+b
# Out:
# array([3, 4, 6])

# %%
np.min(a)
# Out:
# 1

# %%
np.max(b)
# Out:
# 2

# %%
np.average(a)
# Out:
# 3.0

# %% [markdown]
# # UseCase : NPS

# %%
# !gdown 1c0ClC8SrPwJq5rrkyMKyPn80nyHcFikK
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1c0ClC8SrPwJq5rrkyMKyPn80nyHcFikK
# To: /content/survey.txt
# 100% 2.55k/2.55k [00:00<00:00, 3.84MB/s]

# %%
scores = np.loadtxt('survey.txt', dtype='int')
scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4ede40341c95> in <cell line: 1>()
# ----> 1 scores = np.loadtxt('survey.txt', dtype='int')
#       2 scores
#
# NameError: name 'np' is not defined

# %%
scores.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5c8816b9fcc8> in <cell line: 1>()
# ----> 1 scores.shape
#
# NameError: name 'scores' is not defined

# %%
scores.min()

# %%
scores.max()

# %%
scores.mean()

# %%
# detractors
detractors = scores[ scores < 7]

# %%
len(detractors)

# %%
promoters = scores[ scores > 8]

# %%
len(promoters)

# %%
nps = 100*(len(promoters) - len(detractors))/ len(scores)
nps

# %%
round(nps)

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O data.csv
# Out:
# --2022-12-10 04:47:11--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 172.253.119.100, 172.253.119.139, 172.253.119.113, ...
# Connecting to drive.google.com (drive.google.com)|172.253.119.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/rfejgaakes7fscnrcqhqg6salm2rpi8g/1670647575000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=e88dc099-8d6f-4f5d-a3f7-904f4f621c7b [following]
# Warning: wildcards not supported in HTTP.
# --2022-12-10 04:47:11--  https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/rfejgaakes7fscnrcqhqg6salm2rpi8g/1670647575000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=e88dc099-8d6f-4f5d-a3f7-904f4f621c7b
# Resolving doc-0s-68-docs.googleusercontent.com (doc-0s-68-docs.googleusercontent.com)... 209.85.145.132, 2607:f8b0:4001:c1e::84
# Connecting to doc-0s-68-docs.googleusercontent.com (doc-0s-68-docs.googleusercontent.com)|209.85.145.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [text/csv]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>]  81.82K  --.-KB/s    in 0.001s
#
# 2022-12-10 04:47:11 (79.7 MB/s) - ‘data.csv’ saved [83785/83785]

# %%
df = pd.read_csv('data.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.head(n=8)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df['life_exp']
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
df['life_exp'].mean()
# Out:
# 59.474439366197174

# %%
df['life_exp'].min()
# Out:
# 23.599

# %%
df['life_exp'].max()
# Out:
# 82.603

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df['year'].min()
# Out:
# 1952

# %%
df['year'].max()
# Out:
# 2007

# %%
df[['country', 'life_exp', 'population'] ].head()
# Out:
#        country  life_exp  population
# 0  Afghanistan    28.801     8425333
# 1  Afghanistan    30.332     9240934
# 2  Afghanistan    31.997    10267083
# 3  Afghanistan    34.020    11537966
# 4  Afghanistan    36.088    13079460

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
#        'Korea, Rep.', 'Kuwait', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
#        'Madagascar', 'Malawi', 'Malaysia', 'Mali', 'Mauritania',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Norway', 'Oman',
#        'Pakistan', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Puerto Rico', 'Reunion', 'Romania', 'Rwanda',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Sierra Leone', 'Singapore', 'Slovak Republic', 'Slovenia',
#        'Somalia', 'South Africa', 'Spain', 'Sri Lanka', 'Sudan',
#        'Swaziland', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tanzania', 'Thailand', 'Togo', 'Trinidad and Tobago', 'Tunisia',
#        'Turkey', 'Uganda', 'United Kingdom', 'United States', 'Uruguay',
#        'Venezuela', 'Vietnam', 'West Bank and Gaza', 'Yemen, Rep.',
#        'Zambia', 'Zimbabwe'], dtype=object)

# %%
df['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df['year'] + 7
# Out:
# 0       1959
# 1       1964
# 2       1969
# 3       1974
# 4       1979
#         ...
# 1699    1994
# 1700    1999
# 1701    2004
# 1702    2009
# 1703    2014
# Name: year, Length: 1704, dtype: int64

# %%
df['year+7']  = df['year'] + 7

# %%
df['gdp'] = df['gdp_cap'] * df['population']
df.head()
# Out:
#        country  year  population  life_exp     gdp_cap  year+7           gdp
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959  6.567086e+09
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964  7.585449e+09
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969  8.758856e+09
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974  9.648014e+09
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979  9.678553e+09

# %%
df.drop(columns = ['year+7', 'gdp'], inplace = True)
df.head()
# Out:
#        country  year  population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.iloc[3:7]
# Out:
#        country  year  population  life_exp     gdp_cap
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106
# 5  Afghanistan  1977    14880372    38.438  786.113360
# 6  Afghanistan  1982    12881816    39.854  978.011439

# %%
# df.iloc[10]

# %%
df.iloc[ 3:7 , 2:4 ]
# Out:
#    population  life_exp
# 3    11537966    34.020
# 4    13079460    36.088
# 5    14880372    38.438
# 6    12881816    39.854

# %%
df.iloc[5:10, 0]
# Out:
# 5    Afghanistan
# 6    Afghanistan
# 7    Afghanistan
# 8    Afghanistan
# 9    Afghanistan
# Name: country, dtype: object

# %%
df[0:20]
# Out:
#         country  year  population  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333    28.801   779.445314
# 1   Afghanistan  1957     9240934    30.332   820.853030
# 2   Afghanistan  1962    10267083    31.997   853.100710
# 3   Afghanistan  1967    11537966    34.020   836.197138
# 4   Afghanistan  1972    13079460    36.088   739.981106
# 5   Afghanistan  1977    14880372    38.438   786.113360
# 6   Afghanistan  1982    12881816    39.854   978.011439
# 7   Afghanistan  1987    13867957    40.822   852.395945
# 8   Afghanistan  1992    16317921    41.674   649.341395
# 9   Afghanistan  1997    22227415    41.763   635.341351
# 10  Afghanistan  2002    25268405    42.129   726.734055
# 11  Afghanistan  2007    31889923    43.828   974.580338
# 12      Albania  1952     1282697    55.230  1601.056136
# 13      Albania  1957     1476505    59.280  1942.284244
# 14      Albania  1962     1728137    64.820  2312.888958
# 15      Albania  1967     1984060    66.220  2760.196931
# 16      Albania  1972     2263554    67.690  3313.422188
# 17      Albania  1977     2509048    68.930  3533.003910
# 18      Albania  1982     2780097    70.420  3630.880722
# 19      Albania  1987     3075321    72.000  3738.932735

# %%
df.iloc[4:14,  0:3]
# Out:
#         country  year  population
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923
# 12      Albania  1952     1282697
# 13      Albania  1957     1476505

# %%
df [ df['country']=='India' ]
# Out:
#     country  year  population  life_exp      gdp_cap
# 696   India  1952   372000000    37.373   546.565749
# 697   India  1957   409000000    40.249   590.061996
# 698   India  1962   454000000    43.605   658.347151
# 699   India  1967   506000000    47.193   700.770611
# 700   India  1972   567000000    50.651   724.032527
# 701   India  1977   634000000    54.208   813.337323
# 702   India  1982   708000000    56.596   855.723538
# 703   India  1987   788000000    58.553   976.512676
# 704   India  1992   872000000    60.223  1164.406809
# 705   India  1997   959000000    61.765  1458.817442
# 706   India  2002  1034172547    62.879  1746.769454
# 707   India  2007  1110396331    64.698  2452.210407

# %%
df.sort_values(by='life_exp')
# Out:
#                country  year  population  life_exp       gdp_cap
# 1292            Rwanda  1992     7290203    23.599    737.068595
# 0          Afghanistan  1952     8425333    28.801    779.445314
# 552             Gambia  1952      284320    30.000    485.230659
# 36              Angola  1952     4232095    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    30.331    879.787736
# ...                ...   ...         ...       ...           ...
# 1487       Switzerland  2007     7554661    81.701  37506.419070
# 695            Iceland  2007      301931    81.757  36180.789190
# 802              Japan  2002   127065841    82.000  28604.591900
# 671   Hong Kong, China  2007     6980412    82.208  39724.978670
# 803              Japan  2007   127467972    82.603  31656.068060
#
# [1704 rows x 5 columns]

# %%
df.sort_values(by='life_exp', ascending = False)
# Out:
#                country  year  population  life_exp       gdp_cap
# 803              Japan  2007   127467972    82.603  31656.068060
# 671   Hong Kong, China  2007     6980412    82.208  39724.978670
# 802              Japan  2002   127065841    82.000  28604.591900
# 695            Iceland  2007      301931    81.757  36180.789190
# 1487       Switzerland  2007     7554661    81.701  37506.419070
# ...                ...   ...         ...       ...           ...
# 1344      Sierra Leone  1952     2143249    30.331    879.787736
# 36              Angola  1952     4232095    30.015   3520.610273
# 552             Gambia  1952      284320    30.000    485.230659
# 0          Afghanistan  1952     8425333    28.801    779.445314
# 1292            Rwanda  1992     7290203    23.599    737.068595
#
# [1704 rows x 5 columns]

# %%
india = df[ df['country'] == 'India']
india.sort_values(by='life_exp')
# Out:
#     country  year  population  life_exp      gdp_cap
# 696   India  1952   372000000    37.373   546.565749
# 697   India  1957   409000000    40.249   590.061996
# 698   India  1962   454000000    43.605   658.347151
# 699   India  1967   506000000    47.193   700.770611
# 700   India  1972   567000000    50.651   724.032527
# 701   India  1977   634000000    54.208   813.337323
# 702   India  1982   708000000    56.596   855.723538
# 703   India  1987   788000000    58.553   976.512676
# 704   India  1992   872000000    60.223  1164.406809
# 705   India  1997   959000000    61.765  1458.817442
# 706   India  2002  1034172547    62.879  1746.769454
# 707   India  2007  1110396331    64.698  2452.210407

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df[ df['country'] == 'India']['life_exp'])

# %%
plt.plot(df[ df['country'] == 'India']['population'])
